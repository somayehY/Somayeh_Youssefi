# %%
import pandas as pd
import numpy as np

# %% [markdown]
# https://www.census.gov/data/datasets/time-series/demo/popest/2010s-state-total.html

# %%
dfPop = pd.read_excel('C:\\Users\\somfl\\Downloads\\nst-est2019-01.xlsx')

# %%
dfPop.head(15)
# Out:
#    table with row headers in column A and column headers in rows 3 through 4. (leading dots indicate sub-parts)  \
# 0   Table 1. Annual Estimates of the Resident Popu...
# 1                                     Geographic Area
# 2                                                 NaN
# 3                                       United States
# 4                                           Northeast
# 5                                             Midwest
# 6                                               South
# 7                                                West
# 8                                            .Alabama
# 9                                             .Alaska
# 10                                           .Arizona
# 11                                          .Arkansas
# 12                                        .California
# 13                                          .Colorado
# 14                                       .Connecticut
#
# ...

# %%
dfPop.columns =['state', 'Census', 'Estimates Base', '2010','2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']

# %%
dfPop.drop(columns=['Census', 'Estimates Base'], inplace=True)

# %%
dfPop.head(10)
# Out:
#                                                state  \
# 0  Table 1. Annual Estimates of the Resident Popu...
# 1                                    Geographic Area
# 2                                                NaN
# 3                                      United States
# 4                                          Northeast
# 5                                            Midwest
# 6                                              South
# 7                                               West
# 8                                           .Alabama
# 9                                            .Alaska
#
#                                  2010         2011         2012         2013  \
# 0                                 NaN          NaN          NaN          NaN
# 1  Population Estimate (as of July 1)          NaN          NaN          NaN
# 2                                2010       2011.0       2012.0       2013.0
# ...

# %%
dfPop.index
# Out:
# RangeIndex(start=0, stop=66, step=1)

# %%
dfPop = dfPop[8:59]

# %%
dfPop
# Out:
#                     state      2010        2011        2012        2013  \
# 8                .Alabama   4785437   4799069.0   4815588.0   4830081.0
# 9                 .Alaska    713910    722128.0    730443.0    737068.0
# 10               .Arizona   6407172   6472643.0   6554978.0   6632764.0
# 11              .Arkansas   2921964   2940667.0   2952164.0   2959400.0
# 12            .California  37319502  37638369.0  37948800.0  38260787.0
# 13              .Colorado   5047349   5121108.0   5192647.0   5269035.0
# 14           .Connecticut   3579114   3588283.0   3594547.0   3594841.0
# 15              .Delaware    899593    907381.0    915179.0    923576.0
# 16  .District of Columbia    605226    619800.0    634924.0    650581.0
# 17               .Florida  18845537  19053237.0  19297822.0  19545621.0
# 18               .Georgia   9711881   9802431.0   9901430.0   9972479.0
# 19                .Hawaii   1363963   1379329.0   1394804.0   1408243.0
# ...

# %%
dfPop['state'] =dfPop['state'].str[1:]

# %%
dfPop
# Out:
#                    state      2010        2011        2012        2013  \
# 8                Alabama   4785437   4799069.0   4815588.0   4830081.0
# 9                 Alaska    713910    722128.0    730443.0    737068.0
# 10               Arizona   6407172   6472643.0   6554978.0   6632764.0
# 11              Arkansas   2921964   2940667.0   2952164.0   2959400.0
# 12            California  37319502  37638369.0  37948800.0  38260787.0
# 13              Colorado   5047349   5121108.0   5192647.0   5269035.0
# 14           Connecticut   3579114   3588283.0   3594547.0   3594841.0
# 15              Delaware    899593    907381.0    915179.0    923576.0
# 16  District of Columbia    605226    619800.0    634924.0    650581.0
# 17               Florida  18845537  19053237.0  19297822.0  19545621.0
# 18               Georgia   9711881   9802431.0   9901430.0   9972479.0
# 19                Hawaii   1363963   1379329.0   1394804.0   1408243.0
# ...

# %%
state_ab = pd.read_excel('C:\\Users\\somfl\\Downloads\\state_ab.xlsx')

# %%
state_ab = state_ab.drop(['Unnamed: 2'], axis=1)

# %%
state_ab.head()
# Out:
#         State abb
# 0     Alabama  AL
# 1      Alaska  AK
# 2     Arizona  AZ
# 3    Arkansas  AR
# 4  California  CA

# %%
state_ab.columns = ['state', 'abb']

# %%
state_ab.dtypes
# Out:
# state    object
# abb      object
# dtype: object

# %%
dfPop.dtypes
# Out:
# state     object
# 2010      object
# 2011     float64
# 2012     float64
# 2013     float64
# 2014     float64
# 2015     float64
# 2016     float64
# 2017     float64
# 2018     float64
# 2019     float64
# dtype: object

# %%
df = dfPop.join(state_ab.set_index('state'), on='state')

# %%
df
# Out:
#                    state      2010        2011        2012        2013  \
# 8                Alabama   4785437   4799069.0   4815588.0   4830081.0
# 9                 Alaska    713910    722128.0    730443.0    737068.0
# 10               Arizona   6407172   6472643.0   6554978.0   6632764.0
# 11              Arkansas   2921964   2940667.0   2952164.0   2959400.0
# 12            California  37319502  37638369.0  37948800.0  38260787.0
# 13              Colorado   5047349   5121108.0   5192647.0   5269035.0
# 14           Connecticut   3579114   3588283.0   3594547.0   3594841.0
# 15              Delaware    899593    907381.0    915179.0    923576.0
# 16  District of Columbia    605226    619800.0    634924.0    650581.0
# 17               Florida  18845537  19053237.0  19297822.0  19545621.0
# 18               Georgia   9711881   9802431.0   9901430.0   9972479.0
# 19                Hawaii   1363963   1379329.0   1394804.0   1408243.0
# ...

# %%
state_ab.shape
# Out:
# (50, 2)

# %%
df.loc[df['state']=='District of Columbia', 'abb'] = 'DC'

# %%
df['population'] = (df['2010'] + df['2011'] + df['2012'] + df['2013'] + df['2014'] + df['2015'] + df['2016'] +
                    df['2017'] + df['2018'] )//9

# %%
df = df.drop(['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019'], axis=1)

# %%
df
# Out:
#                    state abb  population
# 8                Alabama  AL   4838890.0
# 9                 Alaska  AK    732625.0
# 10               Arizona  AZ   6752305.0
# 11              Arkansas  AR   2968959.0
# 12            California  CA  38518853.0
# 13              Colorado  CO   5363694.0
# 14           Connecticut  CT   3584598.0
# 15              Delaware  DE    932299.0
# 16  District of Columbia  DC    658947.0
# 17               Florida  FL  19957619.0
# 18               Georgia  GA  10095255.0
# 19                Hawaii  HI   1406163.0
# 20                 Idaho  ID   1643776.0
# 21              Illinois  IL  12839047.0
# 22               Indiana  IN   6589257.0
# 23                  Iowa  IA   3104235.0
# 24                Kansas  KS   2894032.0
# 25              Kentucky  KY   4411215.0
# 26             Louisiana  LA   4629186.0
# 27                 Maine  ME   1330601.0
# 28              Maryland  MD   5938231.0
# 29         Massachusetts  MA   6742118.0
# ...

# %%
SavePath = "C:\\Users\\somfl\\Documents\\Data Science Career Track\\LendingClub\\population.csv"
df.to_csv(SavePath, sep =" ", index=False)
